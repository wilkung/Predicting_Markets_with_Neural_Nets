# %%
#create list of all dates from 12/31/99 to 07/31/2015
import datetime

dt = datetime.datetime(1999, 12, 31)
end = datetime.datetime(2015, 7, 31)
step = datetime.timedelta(days=1)

dates = []

while dt < end:
    dates.append(dt.strftime('%Y-%m-%d %H:%M:%S'))
    dt += step

# %%
#write list of dates into master data file (data_file.txt)
type( dates[0] )
dates[0]

data_file = open("data_file.txt", "w")

data_file.write('Date' + "\n")
for date in dates:
    data_file.write(date + ",\n")              

data_file.close()

# %%
# create 2 lists of daily filenames and weekly filenames in directory
from os import listdir
from os.path import isfile, join
import os
import glob

daily_directory = '/Users/wilsonkung/DataScience/metis/projects/project_kojak_wilsonkung/data/Daily'
weekly_directory =  '/Users/wilsonkung/DataScience/metis/projects/project_kojak_wilsonkung/data/weekly'

daily_files = [ f for f in listdir(daily_directory) if isfile(join(daily_directory, f)) and f[0] not in ['_', '.'] ]
weekly_files = [ f for f in listdir(weekly_directory) if isfile(join(weekly_directory, f)) and f[0] not in ['_', '.'] ]

# %%
daily_files
# Out:
# ['AAA10Y.csv',
#  'AAAFF.csv',
#  'AB1020AAAMT.csv',
#  'AB1020AAVOL.csv',
#  'AB14AAAMT.csv',
#  'AB14AAVOL.csv',
#  'AB2140AAAMT.csv',
#  'AB2140AAVOL.csv',
#  'AB4180AAAMT.csv',
#  'AB4180AAVOL.csv',
#  'AB59AAAMT.csv',
#  'AB59AAVOL.csv',
#  'ABGT80AAAMT.csv',
#  'ABGT80AAVOL.csv',
#  'ABSSD678FRBCLE.csv',
#  'ARINFL.csv',
#  'BAA10Y.csv',
#  'BAAFF.csv',
#  'BAMLC0A0CM.csv',
#  'BAMLC0A0CMEY.csv',
#  'BAMLC0A0CMSYTW.csv',
#  'BAMLC0A1CAAA.csv',
#  'BAMLC0A1CAAAEY.csv',
#  'BAMLC0A1CAAASYTW.csv',
#  'BAMLC0A2CAA.csv',
#  'BAMLC0A2CAAEY.csv',
#  'BAMLC0A2CAASYTW.csv',
#  'BAMLC0A3CA.csv',
#  'BAMLC0A3CAEY.csv',
#  'BAMLC0A3CASYTW.csv',
#  'BAMLC0A4CBBB.csv',
#  'BAMLC0A4CBBBEY.csv',
#  'BAMLC0A4CBBBSYTW.csv',
#  'BAMLC1A0C13Y.csv',
#  'BAMLC1A0C13YEY.csv',
#  'BAMLC1A0C13YSYTW.csv',
#  'BAMLC2A0C35Y.csv',
#  'BAMLC2A0C35YEY.csv',
#  'BAMLC2A0C35YSYTW.csv',
#  'BAMLC3A0C57Y.csv',
#  'BAMLC3A0C57YEY.csv',
#  'BAMLC3A0C57YSYTW.csv',
#  'BAMLC4A0C710Y.csv',
#  'BAMLC4A0C710YEY.csv',
#  'BAMLC4A0C710YSYTW.csv',
#  'BAMLC7A0C1015Y.csv',
#  'BAMLC7A0C1015YEY.csv',
#  'BAMLC7A0C1015YSYTW.csv',
#  'BAMLC8A0C15PY.csv',
#  'BAMLC8A0C15PYEY.csv',
#  'BAMLC8A0C15PYSYTW.csv',
#  'BAMLCC0A0CMTRIV.csv',
#  'BAMLCC0A1AAATRIV.csv',
#  'BAMLCC0A2AATRIV.csv',
#  'BAMLCC0A3ATRIV.csv',
#  'BAMLCC0A4BBBTRIV.csv',
#  'BAMLCC1A013YTRIV.csv',
#  'BAMLCC2A035YTRIV.csv',
#  'BAMLCC3A057YTRIV.csv',
#  'BAMLCC4A0710YTRIV.csv',
#  'BAMLCC7A01015YTRIV.csv',
#  'BAMLCC8A015PYTRIV.csv',
#  'BAMLEM1BRRAAA2ACRPIEY.csv',
#  'BAMLEM1BRRAAA2ACRPIOAS.csv',
#  'BAMLEM1BRRAAA2ACRPISYTW.csv',
#  'BAMLEM1BRRAAA2ACRPITRIV.csv',
#  'BAMLEM1RAAA2ALCRPIUSEY.csv',
#  'BAMLEM1RAAA2ALCRPIUSOAS.csv',
#  'BAMLEM1RAAA2ALCRPIUSSYTW.csv',
#  'BAMLEM1RAAA2ALCRPIUSTRIV.csv',
#  'BAMLEM2BRRBBBCRPIEY.csv',
#  'BAMLEM2BRRBBBCRPIOAS.csv',
#  'BAMLEM2BRRBBBCRPISYTW.csv',
#  'BAMLEM2BRRBBBCRPITRIV.csv',
#  'BAMLEM2RBBBLCRPIUSEY.csv',
#  'BAMLEM2RBBBLCRPIUSOAS.csv',
#  'BAMLEM2RBBBLCRPIUSSYTW.csv',
#  'BAMLEM2RBBBLCRPIUSTRIV.csv',
#  'BAMLEM3BRRBBCRPIEY.csv',
#  'BAMLEM3BRRBBCRPIOAS.csv',
#  'BAMLEM3BRRBBCRPISYTW.csv',
#  'BAMLEM3BRRBBCRPITRIV.csv',
#  'BAMLEM3RBBLCRPIUSEY.csv',
#  'BAMLEM3RBBLCRPIUSOAS.csv',
#  'BAMLEM3RBBLCRPIUSSYTW.csv',
#  'BAMLEM3RBBLCRPIUSTRIV.csv',
#  'BAMLEM4BRRBLCRPIEY.csv',
#  'BAMLEM4BRRBLCRPIOAS.csv',
#  'BAMLEM4BRRBLCRPISYTW.csv',
#  'BAMLEM4BRRBLCRPITRIV.csv',
#  'BAMLEM4RBLLCRPIUSEY.csv',
#  'BAMLEM4RBLLCRPIUSOAS.csv',
#  'BAMLEM4RBLLCRPIUSSYTW.csv',
#  'BAMLEM4RBLLCRPIUSTRIV.csv',
#  'BAMLEM5BCOCRPIEY.csv',
#  'BAMLEM5BCOCRPIOAS.csv',
#  'BAMLEM5BCOCRPISYTW.csv',
#  'BAMLEM5BCOCRPITRIV.csv',
#  'BAMLEMALLCRPIASIAUSEY.csv',
#  'BAMLEMALLCRPIASIAUSOAS.csv',
#  'BAMLEMALLCRPIASIAUSSYTW.csv',
#  'BAMLEMALLCRPIASIAUSTRIV.csv',
#  'BAMLEMCBPIEY.csv',
#  'BAMLEMCBPIOAS.csv',
#  'BAMLEMCBPISYTW.csv',
#  'BAMLEMCBPITRIV.csv',
#  'BAMLEMCLLCRPIUSEY.csv',
#  'BAMLEMCLLCRPIUSOAS.csv',
#  'BAMLEMCLLCRPIUSSYTW.csv',
#  'BAMLEMCLLCRPIUSTRIV.csv',
#  'BAMLEMEBCRPIEEY.csv',
#  'BAMLEMEBCRPIEOAS.csv',
#  'BAMLEMEBCRPIESYTW.csv',
#  'BAMLEMEBCRPIETRIV.csv',
#  'BAMLEMELLCRPIEMEAUSEY.csv',
#  'BAMLEMELLCRPIEMEAUSOAS.csv',
#  'BAMLEMELLCRPIEMEAUSSYTW.csv',
#  'BAMLEMELLCRPIEMEAUSTRIV.csv',
#  'BAMLEMFLFLCRPIUSEY.csv',
#  'BAMLEMFLFLCRPIUSOAS.csv',
#  'BAMLEMFLFLCRPIUSSYTW.csv',
#  'BAMLEMFLFLCRPIUSTRIV.csv',
#  'BAMLEMFSFCRPIEY.csv',
#  'BAMLEMFSFCRPIOAS.csv',
#  'BAMLEMFSFCRPISYTW.csv',
#  'BAMLEMFSFCRPITRIV.csv',
#  'BAMLEMHBHYCRPIEY.csv',
#  'BAMLEMHBHYCRPIOAS.csv',
#  'BAMLEMHBHYCRPISYTW.csv',
#  'BAMLEMHBHYCRPITRIV.csv',
#  'BAMLEMHGHGLCRPIUSEY.csv',
#  'BAMLEMHGHGLCRPIUSOAS.csv',
#  'BAMLEMHGHGLCRPIUSSYTW.csv',
#  'BAMLEMHGHGLCRPIUSTRIV.csv',
#  'BAMLEMHYHYLCRPIUSEY.csv',
#  'BAMLEMHYHYLCRPIUSOAS.csv',
#  'BAMLEMHYHYLCRPIUSSYTW.csv',
#  'BAMLEMHYHYLCRPIUSTRIV.csv',
#  'BAMLEMIBHGCRPIEY.csv',
#  'BAMLEMIBHGCRPIOAS.csv',
#  'BAMLEMIBHGCRPISYTW.csv',
#  'BAMLEMIBHGCRPITRIV.csv',
#  'BAMLEMLLLCRPILAUSEY.csv',
#  'BAMLEMLLLCRPILAUSOAS.csv',
#  'BAMLEMLLLCRPILAUSSYTW.csv',
#  'BAMLEMLLLCRPILAUSTRIV.csv',
#  'BAMLEMNFNFLCRPIUSEY.csv',
#  'BAMLEMNFNFLCRPIUSOAS.csv',
#  'BAMLEMNFNFLCRPIUSSYTW.csv',
#  'BAMLEMNFNFLCRPIUSTRIV.csv',
#  'BAMLEMNSNFCRPIEY.csv',
#  'BAMLEMNSNFCRPIOAS.csv',
#  'BAMLEMNSNFCRPISYTW.csv',
#  'BAMLEMNSNFCRPITRIV.csv',
#  'BAMLEMPBPUBSICRPIEY.csv',
#  'BAMLEMPBPUBSICRPIOAS.csv',
#  'BAMLEMPBPUBSICRPISYTW.csv',
#  'BAMLEMPBPUBSICRPITRIV.csv',
#  'BAMLEMPTPRVICRPIEY.csv',
#  'BAMLEMPTPRVICRPIOAS.csv',
#  'BAMLEMPTPRVICRPISYTW.csv',
#  'BAMLEMPTPRVICRPITRIV.csv',
#  'BAMLEMPUPUBSLCRPIUSEY.csv',
#  'BAMLEMPUPUBSLCRPIUSOAS.csv',
#  'BAMLEMPUPUBSLCRPIUSSYTW.csv',
#  'BAMLEMPUPUBSLCRPIUSTRIV.csv',
#  'BAMLEMPVPRIVSLCRPIUSEY.csv',
#  'BAMLEMPVPRIVSLCRPIUSOAS.csv',
#  'BAMLEMPVPRIVSLCRPIUSSYTW.csv',
#  'BAMLEMPVPRIVSLCRPIUSTRIV.csv',
#  'BAMLEMRACRPIASIAEY.csv',
#  'BAMLEMRACRPIASIAOAS.csv',
#  'BAMLEMRACRPIASIASYTW.csv',
#  'BAMLEMRACRPIASIATRIV.csv',
#  'BAMLEMRECRPIEMEAEY.csv',
#  'BAMLEMRECRPIEMEAOAS.csv',
#  'BAMLEMRECRPIEMEASYTW.csv',
#  'BAMLEMRECRPIEMEATRIV.csv',
#  'BAMLEMRLCRPILAEY.csv',
#  'BAMLEMRLCRPILAOAS.csv',
#  'BAMLEMRLCRPILASYTW.csv',
#  'BAMLEMRLCRPILATRIV.csv',
#  'BAMLEMUBCRPIUSEY.csv',
#  'BAMLEMUBCRPIUSOAS.csv',
#  'BAMLEMUBCRPIUSSYTW.csv',
#  'BAMLEMUBCRPIUSTRIV.csv',
#  'BAMLEMXOCOLCRPIUSEY.csv',
#  'BAMLEMXOCOLCRPIUSOAS.csv',
#  'BAMLEMXOCOLCRPIUSSYTW.csv',
#  'BAMLEMXOCOLCRPIUSTRIV.csv',
#  'BAMLH0A0HYM2.csv',
#  'BAMLH0A0HYM2EY.csv',
#  'BAMLH0A0HYM2SYTW.csv',
#  'BAMLH0A1HYBB.csv',
#  'BAMLH0A1HYBBEY.csv',
#  'BAMLH0A1HYBBSYTW.csv',
#  'BAMLH0A2HYB.csv',
#  'BAMLH0A2HYBEY.csv',
#  'BAMLH0A2HYBSYTW.csv',
#  'BAMLH0A3HYC.csv',
#  'BAMLH0A3HYCEY.csv',
#  'BAMLH0A3HYCSYTW.csv',
#  'BAMLHE00EHYIEY.csv',
#  'BAMLHE00EHYIOAS.csv',
#  'BAMLHE00EHYISYTW.csv',
#  'BAMLHE00EHYITRIV.csv',
#  'BAMLHYH0A0HYM2TRIV.csv',
#  'BAMLHYH0A1BBTRIV.csv',
#  'BAMLHYH0A2BTRIV.csv',
#  'BAMLHYH0A3CMTRIV.csv',
#  'BBSD678FRBCLE.csv',
#  'CBSD678FRBCLE.csv',
#  'CFSI.csv',
#  'CHF12MD156N.csv',
#  'CHF1MTD156N.csv',
#  'CHF1WKD156N.csv',
#  'CHF2MTD156N.csv',
#  'CHF3MTD156N.csv',
#  'CHF6MTD156N.csv',
#  'CHFONTD156N.csv',
#  'CISD678FRBCLE.csv',
#  'CMBSSD678FRBCLE.csv',
#  'CMRKTSD678FRBCLE.csv',
#  'CPFF.csv',
#  'CPTBSD678FRBCLE.csv',
#  'CRESD678FRBCLE.csv',
#  'DAAA.csv',
#  'DBAA.csv',
#  'DCOILBRENTEU.csv',
#  'DCOILWTICO.csv',
#  'DCPF1M.csv',
#  'DCPF2M.csv',
#  'DCPF3M.csv',
#  'DCPN2M.csv',
#  'DCPN30.csv',
#  'DCPN3M.csv',
#  'DDFUELLA.csv',
#  'DDFUELNYH.csv',
#  'DDFUELUSGULF.csv',
#  'DED1.csv',
#  'DED3.csv',
#  'DED6.csv',
#  'DEXBZUS.csv',
#  'DEXCAUS.csv',
#  'DEXCHUS.csv',
#  'DEXDNUS.csv',
#  'DEXHKUS.csv',
#  'DEXINUS.csv',
#  'DEXJPUS.csv',
#  'DEXKOUS.csv',
#  'DEXMAUS.csv',
#  'DEXMXUS.csv',
#  'DEXNOUS.csv',
#  'DEXSDUS.csv',
#  'DEXSFUS.csv',
#  'DEXSIUS.csv',
#  'DEXSLUS.csv',
#  'DEXSZUS.csv',
#  'DEXTAUS.csv',
#  'DEXTHUS.csv',
#  'DEXUSAL.csv',
#  'DEXUSEU.csv',
#  'DEXUSNZ.csv',
#  'DEXUSUK.csv',
#  'DEXVZUS.csv',
#  'DFEDTARL.csv',
#  'DFEDTARU.csv',
#  'DFF.csv',
#  'DFII10.csv',
#  'DFII20.csv',
#  'DFII30.csv',
#  'DFII5.csv',
#  'DFII7.csv',
#  'DGASNYH.csv',
#  'DGASUSGULF.csv',
#  'DGS1.csv',
#  'DGS10.csv',
#  'DGS1MO.csv',
#  'DGS2.csv',
#  'DGS20.csv',
#  'DGS3.csv',
#  'DGS30.csv',
#  'DGS3MO.csv',
#  'DGS5.csv',
#  'DGS6MO.csv',
#  'DGS7.csv',
#  'DHHNGSP.csv',
#  'DHOILNYH.csv',
#  'DJCA.csv',
#  'DJFUELUSGULF.csv',
#  'DJIA.csv',
#  'DJTA.csv',
#  'DJUA.csv',
#  'DLTIIT.csv',
#  'DPCREDIT.csv',
#  'DPRIME.csv',
#  'DPROPANEMBTX.csv',
#  'DRGASLA.csv',
#  'DSWP1.csv',
#  'DSWP10.csv',
#  'DSWP2.csv',
#  'DSWP3.csv',
#  'DSWP30.csv',
#  'DSWP4.csv',
#  'DSWP5.csv',
#  'DSWP7.csv',
#  'DTB1YR.csv',
#  'DTB3.csv',
#  'DTB4WK.csv',
#  'DTB6.csv',
#  'DTP10J16.csv',
#  'DTP10J17.csv',
#  'DTP10J18.csv',
#  'DTP10J19.csv',
#  'DTP10J20.csv',
#  'DTP10J21.csv',
#  'DTP10J22.csv',
#  'DTP10J23.csv',
#  'DTP10J24.csv',
#  'DTP10L15.csv',
#  'DTP10L16.csv',
#  'DTP10L17.csv',
#  'DTP10L18.csv',
#  'DTP10L19.csv',
#  'DTP10L20.csv',
#  'DTP10L21.csv',
#  'DTP10L22.csv',
#  'DTP10L23.csv',
#  'DTP10L24.csv',
#  'DTP20J25.csv',
#  'DTP20J26.csv',
#  'DTP20J27.csv',
#  'DTP20J28.csv',
#  'DTP20J29.csv',
#  'DTP30A28.csv',
#  'DTP30A29.csv',
#  'DTP30F40.csv',
#  'DTP30F41.csv',
#  'DTP30F42.csv',
#  'DTP30F43.csv',
#  'DTP30F44.csv',
#  'DTP30F45.csv',
#  'DTP3HA32.csv',
#  'DTP5A16.csv',
#  'DTP5A17.csv',
#  'DTP5A18.csv',
#  'DTP5A19.csv',
#  'DTWEXB.csv',
#  'DTWEXM.csv',
#  'DTWEXO.csv',
#  'EQMRKTSD678FRBCLE.csv',
#  'EUR12MD156N.csv',
#  'EUR1MTD156N.csv',
#  'EUR1WKD156N.csv',
#  'EUR2MTD156N.csv',
#  'EUR3MTD156N.csv',
#  'EUR6MTD156N.csv',
#  'EURONTD156N.csv',
#  'EVZCLS.csv',
#  'FEMRKTSD678FRBCLE.csv',
#  'FIN1020AAAMT.csv',
#  'FIN1020AAVOL.csv',
#  'FIN14AAAMT.csv',
#  'FIN14AAVOL.csv',
#  'FIN2140AAAMT.csv',
#  'FIN2140AAVOL.csv',
#  'FIN4180AAAMT.csv',
#  'FIN4180AAVOL.csv',
#  'FIN59AAAMT.csv',
#  'FIN59AAVOL.csv',
#  'FINBETAD678FRBCLE.csv',
#  'FINGT80AAAMT.csv',
#  'FINGT80AAVOL.csv',
#  'GBP12MD156N.csv',
#  'GBP1MTD156N.csv',
#  'GBP1WKD156N.csv',
#  'GBP2MTD156N.csv',
#  'GBP3MTD156N.csv',
#  'GBP6MTD156N.csv',
#  'GBPONTD156N.csv',
#  'GOLDAMGBD228NLBM.csv',
#  'GOLDAMGBD229NLBM.csv',
#  'GOLDAMGBD230NLBM.csv',
#  'GOLDPMGBD228NLBM.csv',
#  'GOLDPMGBD229NLBM.csv',
#  'GOLDPMGBD230NLBM.csv',
#  'GVZCLS.csv',
#  'IBCOBD678FRBCLE.csv',
#  'IBLSD678FRBCLE.csv',
#  'IBMRKTSD678FRBCLE.csv',
#  'JPY12MD156N.csv',
#  'JPY1MTD156N.csv',
#  'JPY1WKD156N.csv',
#  'JPY2MTD156N.csv',
#  'JPY3MTD156N.csv',
#  'JPY6MTD156N.csv',
#  'JPYONTD156N.csv',
#  'LQTYSD678FRBCLE.csv',
#  'MKT1020MKTAMT.csv',
#  'MKT1020MKTVOL.csv',
#  'MKT14MKTAMT.csv',
#  'MKT14MKTVOL.csv',
#  'MKT2140MKTAMT.csv',
#  'MKT2140MKTVOL.csv',
#  'MKT4180MKTAMT.csv',
#  'MKT4180MKTVOL.csv',
#  'MKT59MKTAMT.csv',
#  'MKT59MKTVOL.csv',
#  'MKTGT80MKTAMT.csv',
#  'MKTGT80MKTVOL.csv',
#  'NASDAQ100.csv',
#  'NASDAQCOM.csv',
#  'NIKKEI225.csv',
#  'NONFIN1020A2P2AMT.csv',
#  'NONFIN1020A2P2VOL.csv',
#  'NONFIN1020AAAMT.csv',
#  'NONFIN1020AAVOL.csv',
#  'NONFIN14A2P2AMT.csv',
#  'NONFIN14A2P2VOL.csv',
#  'NONFIN14AAAMT.csv',
#  'NONFIN14AAVOL.csv',
#  'NONFIN2140A2P2AMT.csv',
#  'NONFIN2140A2P2VOL.csv',
#  'NONFIN2140AAAMT.csv',
#  'NONFIN2140AAVOL.csv',
#  'NONFIN4180A2P2AMT.csv',
#  'NONFIN4180A2P2VOL.csv',
#  'NONFIN4180AAAMT.csv',
#  'NONFIN4180AAVOL.csv',
#  'NONFIN59A2P2AMT.csv',
#  'NONFIN59A2P2VOL.csv',
#  'NONFIN59AAAMT.csv',
#  'NONFIN59AAVOL.csv',
#  'NONFINGT80A2P2AMT.csv',
#  'NONFINGT80A2P2VOL.csv',
#  'NONFINGT80AAAMT.csv',
#  'NONFINGT80AAVOL.csv',
#  'OVXCLS.csv',
#  'R2500GRPR.csv',
#  'R2500GRTR.csv',
#  'R2500VLPR.csv',
#  'R2500VLTR.csv',
#  'REMRKTD678FRBCLE.csv',
#  'RIFSPPAAAD01NB.csv',
#  'RIFSPPAAAD07NB.csv',
#  'RIFSPPAAAD15NB.csv',
#  'RIFSPPAAAD30NB.csv',
#  'RIFSPPAAAD60NB.csv',
#  'RIFSPPAAAD90NB.csv',
#  'RIFSPPFAAD01NB.csv',
#  'RIFSPPFAAD07NB.csv',
#  'RIFSPPFAAD15NB.csv',
#  'RIFSPPFAAD30NB.csv',
#  'RIFSPPFAAD60NB.csv',
#  'RIFSPPFAAD90NB.csv',
#  'RIFSPPNA2P2D01NB.csv',
#  'RIFSPPNA2P2D07NB.csv',
#  'RIFSPPNA2P2D15NB.csv',
#  'RIFSPPNA2P2D30NB.csv',
#  'RIFSPPNA2P2D60NB.csv',
#  'RIFSPPNA2P2D90NB.csv',
#  'RIFSPPNAAD01NB.csv',
#  'RIFSPPNAAD07NB.csv',
#  'RIFSPPNAAD15NB.csv',
#  'RIFSPPNAAD30NB.csv',
#  'RIFSPPNAAD60NB.csv',
#  'RIFSPPNAAD90NB.csv',
#  'RMBSSD678FRBCLE.csv',
#  'RMIDGRPR.csv',
#  'RMIDGRTR.csv',
#  'RMIDVLPR.csv',
#  'RMIDVLTR.csv',
#  'RRESD678FRBCLE.csv',
#  'RTOP200GPR.csv',
#  'RTOP200GTR.csv',
#  'RTOP200VPR.csv',
#  'RTOP200VTR.csv',
#  'RU1000GPR.csv',
#  'RU1000GTR.csv',
#  'RU1000PR.csv',
#  'RU1000TR.csv',
#  'RU1000VPR.csv',
#  'RU1000VTR.csv',
#  'RU2000GPR.csv',
#  'RU2000GTR.csv',
#  'RU2000PR.csv',
#  'RU2000TR.csv',
#  'RU2000VPR.csv',
#  'RU2000VTR.csv',
#  'RU2500PR.csv',
#  'RU2500TR.csv',
#  'RU3000GPR.csv',
#  'RU3000GTR.csv',
#  'RU3000PR.csv',
#  'RU3000TR.csv',
#  'RU3000VPR.csv',
#  'RU3000VTR.csv',
#  'RUMIDCAPPR.csv',
#  'RUMIDCAPTR.csv',
#  'RUTOP200PR.csv',
#  'RUTOP200TR.csv',
#  'RVXCLS.csv',
#  'SMCD678FRBCLE.csv',
#  'SMRKTD678FRBCLE.csv',
#  'SP500.csv',
#  'T10Y2Y.csv',
#  'T10Y3M.csv',
#  'T10YFF.csv',
#  'T10YIE.csv',
#  'T1YFF.csv',
#  'T3MFF.csv',
#  'T5YFF.csv',
#  'T5YIE.csv',
#  'T5YIFR.csv',
#  'T6MFF.csv',
#  'TEDRATE.csv',
#  'TYCSD678FRBCLE.csv',
#  'USD12MD156N.csv',
#  'USD1MTD156N.csv',
#  'USD1WKD156N.csv',
#  'USD2MTD156N.csv',
#  'USD3MTD156N.csv',
#  'USD6MTD156N.csv',
#  'USDONTD156N.csv',
#  'USEPUINDXD.csv',
#  'USINFL.csv',
#  'VIXCLS.csv',
#  'VXAPLCLS.csv',
#  'VXAZNCLS.csv',
#  'VXDCLS.csv',
#  'VXEEMCLS.csv',
#  'VXEWZCLS.csv',
#  'VXFXICLS.csv',
#  'VXGDXCLS.csv',
#  'VXGOGCLS.csv',
#  'VXGSCLS.csv',
#  'VXIBMCLS.csv',
#  'VXNCLS.csv',
#  'VXSLVCLS.csv',
#  'VXTYN.csv',
#  'VXVCLS.csv',
#  'VXXLECLS.csv',
#  'WDCD678FRBCLE.csv',
#  'WILL2500IND.csv',
#  'WILL2500INDGR.csv',
#  'WILL2500INDVAL.csv',
#  'WILL2500PR.csv',
#  'WILL2500PRGR.csv',
#  'WILL2500PRVAL.csv',
#  'WILL4500IND.csv',
#  'WILL4500PR.csv',
#  'WILL5000IND.csv',
#  'WILL5000INDFC.csv',
#  'WILL5000PR.csv',
#  'WILL5000PRFC.csv',
#  'WILLLRGCAP.csv',
#  'WILLLRGCAPGR.csv',
#  'WILLLRGCAPGRPR.csv',
#  'WILLLRGCAPPR.csv',
#  'WILLLRGCAPVAL.csv',
#  'WILLLRGCAPVALPR.csv',
#  'WILLMICROCAP.csv',
#  'WILLMICROCAPPR.csv',
#  'WILLMIDCAP.csv',
#  'WILLMIDCAPGR.csv',
#  'WILLMIDCAPGRPR.csv',
#  'WILLMIDCAPPR.csv',
#  'WILLMIDCAPVAL.csv',
#  'WILLMIDCAPVALPR.csv',
#  'WILLREITIND.csv',
#  'WILLREITPR.csv',
#  'WILLRESIND.csv',
#  'WILLRESIPR.csv',
#  'WILLSMLCAP.csv',
#  'WILLSMLCAPGR.csv',
#  'WILLSMLCAPGRPR.csv',
#  'WILLSMLCAPPR.csv',
#  'WILLSMLCAPVAL.csv',
#  'WILLSMLCAPVALPR.csv',
#  'WLEMUINDXD.csv']

# %%
import pandas
data_df = pandas.read_csv('data_file.txt')

# %%
data_df
# Out:
#                      Date  Unnamed: 1
# 0     1999-12-31 00:00:00         NaN
# 1     2000-01-01 00:00:00         NaN
# 2     2000-01-02 00:00:00         NaN
# 3     2000-01-03 00:00:00         NaN
# 4     2000-01-04 00:00:00         NaN
# 5     2000-01-05 00:00:00         NaN
# 6     2000-01-06 00:00:00         NaN
# 7     2000-01-07 00:00:00         NaN
# 8     2000-01-08 00:00:00         NaN
# 9     2000-01-09 00:00:00         NaN
# 10    2000-01-10 00:00:00         NaN
# 11    2000-01-11 00:00:00         NaN
# 12    2000-01-12 00:00:00         NaN
# 13    2000-01-13 00:00:00         NaN
# 14    2000-01-14 00:00:00         NaN
# 15    2000-01-15 00:00:00         NaN
# 16    2000-01-16 00:00:00         NaN
# 17    2000-01-17 00:00:00         NaN
# 18    2000-01-18 00:00:00         NaN
# 19    2000-01-19 00:00:00         NaN
# 20    2000-01-20 00:00:00         NaN
# 21    2000-01-21 00:00:00         NaN
# 22    2000-01-22 00:00:00         NaN
# 23    2000-01-23 00:00:00         NaN
# 24    2000-01-24 00:00:00         NaN
# 25    2000-01-25 00:00:00         NaN
# 26    2000-01-26 00:00:00         NaN
# 27    2000-01-27 00:00:00         NaN
# 28    2000-01-28 00:00:00         NaN
# 29    2000-01-29 00:00:00         NaN
# ...                   ...         ...
# 5665  2015-07-05 00:00:00         NaN
# 5666  2015-07-06 00:00:00         NaN
# 5667  2015-07-07 00:00:00         NaN
# 5668  2015-07-08 00:00:00         NaN
# 5669  2015-07-09 00:00:00         NaN
# 5670  2015-07-10 00:00:00         NaN
# 5671  2015-07-11 00:00:00         NaN
# 5672  2015-07-12 00:00:00         NaN
# 5673  2015-07-13 00:00:00         NaN
# 5674  2015-07-14 00:00:00         NaN
# 5675  2015-07-15 00:00:00         NaN
# 5676  2015-07-16 00:00:00         NaN
# 5677  2015-07-17 00:00:00         NaN
# 5678  2015-07-18 00:00:00         NaN
# 5679  2015-07-19 00:00:00         NaN
# 5680  2015-07-20 00:00:00         NaN
# 5681  2015-07-21 00:00:00         NaN
# 5682  2015-07-22 00:00:00         NaN
# 5683  2015-07-23 00:00:00         NaN
# 5684  2015-07-24 00:00:00         NaN
# 5685  2015-07-25 00:00:00         NaN
# 5686  2015-07-26 00:00:00         NaN
# 5687  2015-07-27 00:00:00         NaN
# 5688  2015-07-28 00:00:00         NaN
# 5689  2015-07-29 00:00:00         NaN
# 5690  2015-07-30 00:00:00         NaN
# 5691               AAA10Y         NaN
# 5692               AAA10Y         NaN
# 5693               AAA10Y         NaN
# 5694               AAA10Y         NaN
#
# [5695 rows x 2 columns]

# %%
#insert each daily file's data into master data file

data_file = open("data_file.txt", "w")

for file in daily_files:
    
    f = open('./data/Daily/' + file, 'r')
    data_file.write(file.split('.')[1] + ",\n")

    for line in f:
        date = line.split(',')[0][0]
        data = float( [line.split(',')][0][1]
        
    data_file.write("hello world in the new file\n")

              
data_file.close()
# Out:
#   File "<ipython-input-201-f7d6d703a01a>", line 14
#     data_file.write("hello world in the new file\n")
#             ^
# SyntaxError: invalid syntax

# %%
data_file = open("data_file.txt", "w")
f = open('./data/Daily/' + daily_files[0], 'r')

float( [f.readline().split(',')][0][1]
# Out:
#   File "<ipython-input-202-bfde2a7009bb>", line 4
#     float( [f.readline().split(',')][0][1]
#                                           ^
# SyntaxError: invalid syntax

# %%
data_file = open("data_file.txt", "a")

daily_files[0]
f = open('./data/Daily/' + daily_files[0], 'r')
data_file.write(daily_files[0].split('.')[0] + ",\n")

data_file.close()

# %%
daily_files[0].split('.')[0]+","
# Out:
# 'AAA10Y,'
